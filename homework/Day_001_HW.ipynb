# %%
print ('為什麼這個問題重要?     預測是否被錄取')
print ('資料從何⽽來?           加州大学洛杉矶分校研究生数据集')
print ('資料的型態是什麼?       結構化：表格 數據集')
print ('我們可以回答什什麼問題?     Precision-Recall')
# Out:
# 為什麼這個問題重要?     預測是否被錄取
# 資料從何⽽來?           加州大学洛杉矶分校研究生数据集
# 資料的型態是什麼?       結構化：表格 數據集
# 我們可以回答什什麼問題?     Precision-Recall

# %%
print ('核心問題為何?                 如何配置車輛，讓時間與地理位置相互結合，達到高效        通過預測數據預測上車的人流量大')
print ('料從何而來?                   上車點、時間點、行駛路程、交通堵塞位置、 天氣狀況        打車表、叫車APP、定位器、火車地鐵時間表等')
print ('集而來的資料型態為何?         數值 表格 散點圖像 文字')
print ('要回答的問題，其如何評估?     提前發佈某個可能存在急需上車的地點')
# Out:
# 核心問題為何?                 如何配置車輛，讓時間與地理位置相互結合，達到高效        通過預測數據預測上車的人流量大
# 料從何而來?                   上車點、時間點、行駛路程、交通堵塞位置、 天氣狀況        打車表、叫車APP、定位器、火車地鐵時間表等
# 集而來的資料型態為何?         數值 表格 散點圖像 文字
# 要回答的問題，其如何評估?     提前發佈某個可能存在急需上車的地點

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def MeanAbsoluteError (y,yp):
    MSE = (y-yp)**2
    mse = MSE.sum()/len(yp)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
Mae= MeanAbsoluteError (y, y_hat)

print("The Mean absolute error is %.3f" % (Mae))
# Out:
# The Mean absolute error is 203.870
